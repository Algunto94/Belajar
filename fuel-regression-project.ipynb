# %% [markdown]
# <a href="https://colab.research.google.com/github/Algunto94/Belajar/blob/main/fuel-regression-project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read.me
#
# This notebook demonstrates a simple linear regression model to predict distance traveled (in kilometers) based on fuel consumption (in liters).
#
# ---
#
# ## 📌 Dataset
# The dataset contains two columns:
# - `Liter`: the amount of fuel used
# - `Kilometer`: the distance traveled
#
# 📌 **Source:**
# Data sourced from the book *"Pengenalan Machine Learning dengan Python"* by **Dios Kurniawan**, Chapter 4.
# Used for educational purposes only.

# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.model_selection as ms

# %% [markdown]
# # Load and Preview Dataset

# %%
df = pd.read_csv('bensin.csv')
df.describe()
# Out:
#            Liter   Kilometer
# count  65.000000   65.000000
# mean   26.446154  181.064615
# std     7.424686   49.741763
# min     6.000000   32.000000
# 25%    23.000000  144.000000
# 50%    25.000000  177.000000
# 75%    30.000000  212.000000
# max    45.000000  278.000000

# %% [markdown]
# # Prepare the Data

# %%
# Prepare input and target variables
liter = df[['Liter']]
kilometer = df[['Kilometer']]

# %% [markdown]
# # Train-Test Split

# %%
# Split data into training and testing sets (80/20 split)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)
# Out:
# LinearRegression()

# %% [markdown]
# # Model Training

# %%
# Initialize and fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)
print(model)
# Out:
# LinearRegression()

# %% [markdown]
# # Evaluate the Model

# %%
# Model parameters
print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)

# R² Score
r2 = model.score(X_test, y_test)
print("R² Score:", r2)
# Out:
# Coefficient: [[6.45829591]]
# Intercept: [10.64122249]
# R² Score: 0.9798523775622333

# %% [markdown]
# # Predict on Test Set

# %%
# Predict the test data
y_pred = model.predict(X_test)

# Compare actual vs predicted (first 10)
results = pd.DataFrame({
    'Liter': X_test['Liter'].values.flatten(),
    'Actual KM': y_test['Kilometer'].values.flatten(),
    'Predicted KM': y_pred.flatten()
})
results.head(10)
# Out:
#    Liter  Actual KM  Predicted KM
# 0     15      102.0    107.515661
# 1     25      167.0    172.098620
# 2     25      177.0    172.098620
# 3     23      142.0    159.182028
# 4     20      144.0    139.807141
# 5     40      278.0    268.973059
# 6     30      211.0    204.390100
# 7     35      241.0    236.681579
# 8     10       65.0     75.224182
# 9     36      241.0    243.139875

# %% [markdown]
# # Plot: Regression Line (Training Data)

# %%
plt.scatter(X_train, y_train, color='blue', label='Training Data', edgecolor='k')
plt.xlabel('Fuel Used (Liter)')
plt.ylabel('Distance Traveled (Kilometer)')
plt.title('Fuel Consumption vs Distance')
x_line = np.linspace(X.min(), X.max(), 100)
y_line = model.predict(pd.DataFrame(x_line, columns=['Liter']))
plt.plot(x_line, y_line, color='green', label='Regression Line')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Plot: Actual vs Predicted (Test Set)

# %%
plt.scatter(X_test, y_test, color='orange', label='Actual')
plt.scatter(X_test, y_pred, color='purple', label='Predicted')
plt.xlabel('Fuel Used (Liter)')
plt.ylabel('Distance Traveled (Kilometer)')
plt.title('Actual vs Predicted (Test Set)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## ✅ Conclusion
#
# - The model achieves an R² score of approximately 0.98, which indicates strong predictive performance.
# - The prediction error is relatively small (±10 km).
# - The linear relationship between fuel and distance is well captured by the model.
